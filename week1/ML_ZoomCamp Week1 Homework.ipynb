# %%
import os
print (os.environ['CONDA_DEFAULT_ENV'])
# Out:
# ml-zoomcamp

# %%
import numpy

# %%
numpy.__version__
# Out:
# '1.20.3'

# %%
import pandas as pd

# %%
data = pd.read_csv("data_week1.csv")

# %%
len(data)
# Out:
# 11914

# %%
data.shape
# Out:
# (11914, 16)

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
data['Make'].value_counts().nlargest(3)
# Out:
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Name: Make, dtype: int64

# %%
df = data.query("Make == 'Audi'")['Model']

# %%
len(df.unique())
# Out:
# 34

# %%
len((data.loc[data['Make'] == 'Audi', 'Model']).unique())
# Out:
# 34

# %%
data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
median_ec = data['Engine Cylinders'].median()
median_ec
# Out:
# 6.0

# %%
mode_ec = data['Engine Cylinders'].mode()
mode_ec
# Out:
# 0    4.0
# Name: Engine Cylinders, dtype: float64

# %%
new_mode = data['Engine Cylinders'].fillna(mode_ec).mode()

# %%
new_mode
# Out:
# 0    4.0
# Name: Engine Cylinders, dtype: float64

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df_2 = data[data.Make=='Lotus']

# %%
df_2.head()
# Out:
#        Make  Model  Year             Engine Fuel Type  Engine HP  \
# 3912  Lotus  Elise  2009  premium unleaded (required)      189.0
# 3913  Lotus  Elise  2009  premium unleaded (required)      218.0
# 3914  Lotus  Elise  2009  premium unleaded (required)      189.0
# 3915  Lotus  Elise  2010  premium unleaded (required)      189.0
# 3916  Lotus  Elise  2010  premium unleaded (required)      218.0
#
#       Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 3912               4.0            MANUAL  rear wheel drive              2.0
# 3913               4.0            MANUAL  rear wheel drive              2.0
# 3914               4.0            MANUAL  rear wheel drive              2.0
# 3915               4.0            MANUAL  rear wheel drive              2.0
# 3916               4.0            MANUAL  rear wheel drive              2.0
#
#               Market Category Vehicle Size Vehicle Style  highway MPG  \
# ...

# %%
df_2.shape
# Out:
# (29, 16)

# %%
df_2 = df_2[["Engine HP", "Engine Cylinders"]]

# %%
df_2
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %%
dataframe= df_2.drop_duplicates()

# %%
dataframe
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
X = dataframe.values

# %%
X
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
XTX = X.T.dot(X)

# %%
XTX
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %%
inv_XTX = numpy. linalg. inv(XTX)
inv_XTX
# Out:
# array([[ 5.53084235e-05, -2.94319825e-03],
#        [-2.94319825e-03,  1.60588447e-01]])

# %%
Y = [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800]

# %%
w = inv_XTX.dot(X.T).dot(Y)

# %%
w
# Out:
# array([  4.59494481, -63.56432501])
